# %% [markdown]
# <a href="https://colab.research.google.com/github/Omkar210/Statistics-and-ML/blob/main/Day29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.stats
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from statsmodels.stats import rates
from statsmodels.stats.rates import test_poisson
from statsmodels.stats.rates import test_poisson_2indep
from scipy.stats import chi2
from scipy.stats import f
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
# from category_encoders import BinaryEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import log_loss
from statsmodels.discrete.discrete_model import MNLogit
from statsmodels.miscmodels.ordinal_model import OrderedModel
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import statsmodels.formula.api as smf
from statsmodels.discrete.discrete_model import Poisson as psn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.api import SimpleExpSmoothing
from statsmodels.tsa.api import Holt
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
import tensorflow
from tensorflow.keras.models import Sequential  # helps with the forward and backward propagation
from tensorflow.keras.layers import Dense  # this is for the hidden, input and output layers
from tensorflow.keras.layers import ReLU    # activation function
from tensorflow.keras.layers import Dropout   # switching off the neurons
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
import scipy.cluster.hierarchy as sch
from sklearn.decomposition import PCA
import os
print(os.getcwd())
os.chdir('/content/drive/MyDrive/CDAC')
os.getcwd()
# Out:
# /content
# '/content/drive/MyDrive/CDAC'

# %% [markdown]
# Eigen Vector:
# - Direction of the principal components.
#
# Eigen Value:
# - Amount of variance explained in the direction of eigen vectors.
#
# Co-Variance:
# - magnitude of co-variance is useless, it can be (-inf,inf)
# - sign is important
# - it tells you about the +ve or -ve corelation between two factors but nothe magnitude.
# - Formula:
# $$
# Co-Variance (COV) = \frac{\Sigma^{N}_{i=1} (X_i - \mu_x)(Y_i - \mu_y)}{n - 1}
# $$
# $$
# Co-Relation Coeffient(CORR) = \frac{COV}{\sigma_1 * \sigma_2}
# $$
#
# ---
#
# Characteristic Equation:
# $$
# |R - \lambda I| = 0
# $$
# R => Corealtion Matrix \
# I => Identity Matrix\
# $\lambda$ => eigen value
#
# - Standardization of the values are necessary for PCA and LDA.
# - power of lambda will be decided on number of features.
# - Convert all feature columns into standard column because PCA calculation make will linear combination of all variables

# %% [markdown]
# # Principal Component Analysis (PCA) - Manual Calculation Using Characteristic Equation
#
# ## Step 1: Given Dataset
#
# | Feature 1 | Feature 2 | Feature 3 |
# |------------|------------|------------|
# | 2 | 6 | 8 |
# | 4 | 4 | 5 |
# | 5 | 3 | 9 |
# | 2 | 3 | 9 |
# | 7 | 8 | 7 |
#
# Let
#
# $$
# X=
# \begin{bmatrix}
# 2 & 6 & 8\\
# 4 & 4 & 5\\
# 5 & 3 & 9\\
# 2 & 3 & 9\\
# 7 & 8 & 7
# \end{bmatrix}
# $$
#
# Number of observations:
#
# $$
# n=5
# $$
#
# Number of features:
#
# $$
# p=3
# $$
#
# ---
#
# # Step 2: Compute Mean of Each Feature
#
# For Feature 1:
#
# $$
# \bar{x}_1=\frac{2+4+5+2+7}{5}
# =\frac{20}{5}
# =4
# $$
#
# For Feature 2:
#
# $$
# \bar{x}_2=\frac{6+4+3+3+8}{5}
# =\frac{24}{5}
# =4.8
# $$
#
# For Feature 3:
#
# $$
# \bar{x}_3=\frac{8+5+9+9+7}{5}
# =\frac{38}{5}
# =7.6
# $$
#
# Mean Vector:
#
# $$
# \mu=
# \begin{bmatrix}
# 4\\
# 4.8\\
# 7.6
# \end{bmatrix}
# $$
#
# ---
#
# # Step 3: Mean Center the Dataset
#
# Subtract column means from each feature.
#
# $$
# X_{centered}
# =
# X-\mu
# $$
#
# $$
# =
# \begin{bmatrix}
# -2 & 1.2 & 0.4\\
# 0 & -0.8 & -2.6\\
# 1 & -1.8 & 1.4\\
# -2 & -1.8 & 1.4\\
# 3 & 3.2 & -0.6
# \end{bmatrix}
# $$
#
# ---
#
# # Step 4: Compute Covariance Matrix
#
# Formula:
#
# $$
# C=
# \frac{1}{n-1}
# X_{centered}^{T}
# X_{centered}
# $$
#
# Since:
#
# $$
# n=5
# $$
#
# $$
# n-1=4
# $$
#
# Computing:
#
# $$
# X_{centered}^{T}
# X_{centered}
# =
# \begin{bmatrix}
# 18 & 11 & -2\\
# 11 & 18.8 & -6.4\\
# -2 & -6.4 & 12.8
# \end{bmatrix}
# $$
#
# Therefore:
#
# $$
# C=
# \frac{1}{4}
# \begin{bmatrix}
# 18 & 11 & -2\\
# 11 & 18.8 & -6.4\\
# -2 & -6.4 & 12.8
# \end{bmatrix}
# $$
#
# Covariance Matrix:
#
# $$
# C=
# \begin{bmatrix}
# 4.50 & 2.75 & -0.50\\
# 2.75 & 4.70 & -1.60\\
# -0.50 & -1.60 & 3.20
# \end{bmatrix}
# $$
#
# ---
#
# # Step 5: Find Eigenvalues Using Characteristic Equation
#
# PCA requires solving:
#
# $$
# |C-\lambda I|=0
# $$
#
# Substitute covariance matrix:
#
# $$
# \left|
# \begin{matrix}
# 4.5-\lambda & 2.75 & -0.5\\
# 2.75 & 4.7-\lambda & -1.6\\
# -0.5 & -1.6 & 3.2-\lambda
# \end{matrix}
# \right|
# =0
# $$
#
# Expanding determinant:
#
# $$
# (4.5-\lambda)
# \left[
# (4.7-\lambda)(3.2-\lambda)
# -
# (-1.6)^2
# \right]
# $$
#
# $$
# -
# 2.75
# \left[
# 2.75(3.2-\lambda)
# -
# (-1.6)(-0.5)
# \right]
# $$
#
# $$
# +
# (-0.5)
# \left[
# 2.75(-1.6)
# -
# (4.7-\lambda)(-0.5)
# \right]
# =0
# $$
#
# After simplification:
#
# $$
# \lambda^3
# -
# 12.4\lambda^2
# +
# 41.1575\lambda
# -
# 25.242
# =
# 0
# $$
#
# Characteristic Equation:
#
# $$
# \boxed{
# \lambda^3
# -
# 12.4\lambda^2
# +
# 41.1575\lambda
# -
# 25.242
# =
# 0
# }
# $$
#
# ---
#
# # Step 6: Solve Eigenvalues
#
# Solving the cubic equation gives:
#
# $$
# \lambda_1 \approx 8.09
# $$
#
# $$
# \lambda_2 \approx 3.43
# $$
#
# $$
# \lambda_3 \approx 0.88
# $$
#
# Check:
#
# $$
# 8.09+3.43+0.88
# =
# 12.40
# $$
#
# which equals the trace:
#
# $$
# 4.5+4.7+3.2
# =
# 12.4
# $$
#
# Correct.
#
# ---
#
# # Step 7: Compute Explained Variance
#
# Total Variance:
#
# $$
# \sum \lambda_i
# =
# 8.09+3.43+0.88
# =
# 12.40
# $$
#
# ---
#
# ### Principal Component 1
#
# $$
# EV_1
# =
# \frac{8.09}{12.40}
# \times100
# $$
#
# $$
# EV_1
# =
# 65.24\%
# $$
#
# ---
#
# ### Principal Component 2
#
# $$
# EV_2
# =
# \frac{3.43}{12.40}
# \times100
# $$
#
# $$
# EV_2
# =
# 27.66\%
# $$
#
# ---
#
# ### Principal Component 3
#
# $$
# EV_3
# =
# \frac{0.88}{12.40}
# \times100
# $$
#
# $$
# EV_3
# =
# 7.10\%
# $$
#
# ---
#
# # Step 8: Cumulative Variance
#
# Using first two principal components:
#
# $$
# 65.24+27.66
# =
# 92.90\%
# $$
#
# Thus:
#
# $$
# \boxed{
# PC_1 + PC_2
# }
# $$
#
# retain approximately
#
# $$
# \boxed{
# 92.9\%
# }
# $$
#
# of the total variance.
#
# ---
#
# # Step 9: Find Eigenvectors
#
# For each eigenvalue:
#
# $$
# (C-\lambda I)v=0
# $$
#
# For
#
# $$
# \lambda_1=8.09
# $$
#
# Solve:
#
# $$
# (C-8.09I)v=0
# $$
#
# Resulting normalized eigenvector:
#
# $$
# v_1
# =
# \begin{bmatrix}
# 0.66\\
# 0.68\\
# -0.32
# \end{bmatrix}
# $$
#
# ---
#
# For
#
# $$
# \lambda_2=3.43
# $$
#
# $$
# v_2
# =
# \begin{bmatrix}
# 0.45\\
# -0.67\\
# -0.59
# \end{bmatrix}
# $$
#
# ---
#
# For
#
# $$
# \lambda_3=0.88
# $$
#
# $$
# v_3
# =
# \begin{bmatrix}
# 0.60\\
# -0.30\\
# 0.74
# \end{bmatrix}
# $$
#
# ---
#
# # Step 10: Principal Component Matrix
#
# $$
# P=
# \begin{bmatrix}
# 0.66 & 0.45 & 0.60\\
# 0.68 & -0.67 & -0.30\\
# -0.32 & -0.59 & 0.74
# \end{bmatrix}
# $$
#
# ---
#
# # Step 11: Transform Data
#
# PCA Projection:
#
# $$
# Z=X_{centered}P
# $$
#
# If keeping only first two principal components:
#
# $$
# Z=
# X_{centered}
# \begin{bmatrix}
# 0.66 & 0.45\\
# 0.68 & -0.67\\
# -0.32 & -0.59
# \end{bmatrix}
# $$
#
# This converts:
#
# $$
# 5\times3
# \rightarrow
# 5\times2
# $$
#
# while preserving approximately:
#
# $$
# 92.9\%
# $$
#
# of the information.
#
# ---
#
# # Final PCA Results
#
# ### Eigenvalues
#
# $$
# \lambda_1=8.09
# $$
#
# $$
# \lambda_2=3.43
# $$
#
# $$
# \lambda_3=0.88
# $$
#
# ### Explained Variance
#
# $$
# PC_1=65.24\%
# $$
#
# $$
# PC_2=27.66\%
# $$
#
# $$
# PC_3=7.10\%
# $$
#
# ### Retained Variance
#
# Using first two principal components:
#
# $$
# 92.9\%
# $$
#
# ### Conclusion
#
# The original 3-dimensional dataset can be reduced to 2 dimensions while preserving nearly 93% of the total variance.

# %%
df = pd.read_excel('pca.xlsx')
df.head()

x = df.drop(columns=["Response"])
y = df.Response
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=20)
x_train = sm.add_constant(x_train, prepend=False)

mod1 = sm.Logit(y_train,x_train).fit()
print(mod1.summary())

x_test = sm.add_constant(x_test, prepend=False)
y_pred = mod1.predict(x_test)
y_pred = (y_pred>=0.5).astype(int)
print(confusion_matrix(y_test,y_pred))
# % accuracy on test dataset is 93%

y_pred = mod1.predict(x_train)
y_pred = (y_pred>=0.5).astype(int)
print(confusion_matrix(y_train,y_pred))
# % accuracy on train dataset is 93%
# Out:
# Optimization terminated successfully.
#          Current function value: 0.170808
#          Iterations 10
#                            Logit Regression Results
# ...
# Dep. Variable:               Response   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      393
# Method:                           MLE   Df Model:                            6
# Date:                Sat, 20 Jun 2026   Pseudo R-squ.:                  0.7510
# Time:                        06:08:42   Log-Likelihood:                -68.323
# converged:                       True   LL-Null:                       -274.37
# Covariance Type:            nonrobust   LLR p-value:                 7.004e-86
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X1             0.1179      0.143      0.827      0.408      -0.162       0.397
# ...

# %%
# Covariance Method
df = pd.read_excel('pca.xlsx')
df.head()

x = df.drop(columns=["Response"])
y = df.Response
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=20)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)

cov_matrix = np.cov(x_train_scaled.T)
eigen_values, eigen_vectors = np.linalg.eig(cov_matrix)

# %%
# PCA method
df = pd.read_excel('pca.xlsx')
df.head()

x = df.drop(columns=["Response"])
y = df.Response
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=20)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)

pca= PCA()
pca.fit(x_train_scaled)
eig_pca = pca.explained_variance_
eig_pca   # eigen values in descending order

eigen_vect = pca.components_.T   # eigen vectors

# %%
# Dataset Loading
df = pd.read_excel('pca.xlsx')
df.head()

# Train-Test Split
x = df.drop(columns=["Response"])
y = df.Response
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=20)

# Standardization
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# PCA model Fit
pca = PCA(n_components=2)
x_train_pc = pca.fit_transform(x_train_scaled)
x_test_pc = pca.transform(x_test_scaled)

# Creating DataFrame of max variation explained
x_train_pc = pd.DataFrame(x_train_pc, columns=['PC1','PC2'], index = x_train.index)
x_test_pc = pd.DataFrame(x_test_pc, columns=['PC1','PC2'], index = x_test.index)

# %%
# Model on PC vectors
x_train_pc1 = sm.add_constant(x_train_pc, prepend=False)
x_test_pc1 = sm.add_constant(x_test_pc, prepend=False)

mod2pca = sm.Logit(y_train,x_train_pc1).fit()

y_pred = mod2pca.predict(x_test_pc1)
y_pred = (y_pred>=0.5).astype(int)
print(confusion_matrix(y_test,y_pred))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.359350
#          Iterations 7
# [[43 10]
#  [12 35]]
